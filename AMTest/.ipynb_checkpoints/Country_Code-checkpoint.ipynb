# %%
import pandas as pd

# %%
pd.read_csv("https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv")
# Out:
#                                                   name alpha-2 alpha-3  \
# 0                                          Afghanistan      AF     AFG
# 1                                        Åland Islands      AX     ALA
# 2                                              Albania      AL     ALB
# 3                                              Algeria      DZ     DZA
# 4                                       American Samoa      AS     ASM
# 5                                              Andorra      AD     AND
# 6                                               Angola      AO     AGO
# 7                                             Anguilla      AI     AIA
# 8                                           Antarctica      AQ     ATA
# 9                                  Antigua and Barbuda      AG     ATG
# 10                                           Argentina      AR     ARG
# 11                                             Armenia      AM     ARM
# ...

# %%
pd.read_csv("cost_of_living_data_combine.csv")
